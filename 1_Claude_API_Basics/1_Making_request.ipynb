# %%
# Install dependencies
# %pip install -q anthropic python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load environment variables from .env file
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create API client

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %% [markdown]
# **Making a request to LLM**
# - Generates text by making a request to LLM
# - Message Types:
#     - User (Messages by User)
#     - Assistant (Messages by LLM)

# %%
# Make a request to the API

message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "Write a sonnet about the beauty of nature.",
        }
    ]
)

# %%
print(message.content[0].text)
# Out:
# # Nature's Eternal Song
#
# The morning sun ignites the dewy hills,
# And paints the sky in amber, rose, and gold,
# While mountain streams cascade in silver rills,
# And ancient forests whisper stories old.
#
# The meadows blush with wildflowers unplanned,
# Where honeybees pursue their fragrant art,
# And ocean waves reshape the yielding sand,
# As tides perform their everlasting part.
#
# In autumn, leaves surrender, bronze and red,
# Descending soft as prayers upon the ground,
# And winter lays its quiet, silver thread
# Across the earth without a single sound.
#
# Through every season, nature holds her grace,
# A timeless wonder no one can replace.
#
# ---
#
# *Written in Shakespearean sonnet form: three quatrains (ABAB) exploring nature through the seasons, concluding with a rhyming couplet that captures her enduring beauty.*
